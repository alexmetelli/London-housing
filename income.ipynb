# %%
import pandas as pd

# %%
data = pd.read_excel('/home/alex/Documents/LondonHousing/cut_income-of-tax-payers.xlsx')

# %%
data
# Out:
#                       Area  Number of Individuals  Mean £  Median £  \
# 0           City of London                  11000  148000     60000
# 1     Barking and Dagenham                  85000   27400     23900
# 2                   Barnet                 188000   49500     28700
# 3                   Bexley                 122000   33500     26900
# 4                    Brent                 155000   35400     24700
# 5                  Bromley                 174000   45500     32000
# 6                   Camden                 101000   92600     37300
# 7                  Croydon                 183000   35600     27500
# 8                   Ealing                 170000   39700     26700
# 9                  Enfield                 144000   36200     26300
# 10               Greenwich                 124000   40200     27600
# 11                 Hackney                 112000   43100     29400
# 12  Hammersmith and Fulham                  94000   73200     33200
# ...
